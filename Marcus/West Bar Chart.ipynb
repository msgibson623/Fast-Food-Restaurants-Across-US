# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import requests
import sys
import matplotlib.pyplot as plt

# Google API Key
from config import gkey
pd.set_option("display.max_rows", None)

# %%
fastfood_us_df = pd.read_csv("fastfood_census.csv")
fastfood_us_df.head()
# Out:
#              name country   latitude  longitude  \
# 0  Sonic Drive-In      US  29.814697 -90.814742
# 1       Taco Bell      US  35.803788 -83.580553
# 2          Arby's      US  35.782339 -83.551408
# 3  Steak 'n Shake      US  33.562738 -84.321143
# 4         Wendy's      US  42.368823 -83.138251
#
#                                  Street Adress       province state   region  \
# 0        800 N Canal Blvd, Thibodaux, LA 70301      Thibodaux    LA    South
# 1  206 Wears Valley Rd, Pigeon Forge, TN 37863   Pigeon Forge    TN    South
# 2         3652 Parkway, Pigeon Forge, TN 37863   Pigeon Forge    TN    South
# 3       2118 Mt Zion Parkway, Morrow, GA 30260         Morrow    GA    South
# 4      9768 Grand River Ave, Detroit, MI 48204        Detroit    MI  Midwest
#
#              division  price_level  rating  user_ratings_total
# 0  West South Central          1.0     4.3               479.0
# 1  East South Central          1.0     3.3              1029.0
# ...

# %%
dl=fastfood_us_df.groupby(['region', 'state']).agg({'name':'count'})
dl
# Out:
#                  name
# region    state
# Midwest   IA       96
#           IL      300
#           IN      201
#           KS       55
#           MI      310
#           MN      160
#           MO      128
#           ND       29
#           NE       62
#           OH      434
#           SD       38
#           WI      144
# Northeast CT       39
#           MA      141
#           ME       16
#           NH       21
#           NJ       94
#           NY      263
#           PA      272
#           RI        8
#           VT       11
# South     AL        6
#           AR       74
#           DE       27
#           FL      477
#           GA      332
#           KY      131
#           LA      158
#           MD      132
#           MS       44
#           NC      235
#           OK      121
#           SC      155
#           TN      256
#           TX      579
#           VA      201
#           WV       50
# West      AK        9
#           AZ      252
# ...

# %%
State = ["AK", "AZ", "CA", "CO", "HI", "ID", "MT", "NM", "NV", "OR", "UT", "WA", "WY"]
name = [9, 252, 883, 114, 24, 42, 32, 58, 88, 128, 48, 152, 27]
x_axis = np.arange(len(name))
plt.bar(x_axis, name, color="g", align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 13 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, State)
# Out:
# ([<matplotlib.axis.XTick at 0x7faa2a3a01c0>,
# ...
#  [Text(0, 0, 'AK'),
#   Text(1, 0, 'AZ'),
#   Text(2, 0, 'CA'),
#   Text(3, 0, 'CO'),
#   Text(4, 0, 'HI'),
#   Text(5, 0, 'ID'),
#   Text(6, 0, 'MT'),
#   Text(7, 0, 'NM'),
#   Text(8, 0, 'NV'),
#   Text(9, 0, 'OR'),
#   Text(10, 0, 'UT'),
#   Text(11, 0, 'WA'),
#   Text(12, 0, 'WY')])

# %%
plt.title("Name Count for the West")
plt.xlabel("State")
plt.ylabel("Amount of Resturant Per State")
# Out:
# Text(38.097222222222214, 0.5, 'Amount of Resturant Per State')

# %%
plt.show()
