# %%
import pandas as pd
import numpy as np
import requests
import sys

# Google API Key
from config import gkey

# %%
fastfood_us_df = pd.read_csv("fastfood_restaurant_review.csv")

# %%
fastfood_us_df.head()
# Out:
#              name country   latitude  longitude  \
# 0  Sonic Drive-In      US  29.814697 -90.814742
# 1       Taco Bell      US  35.803788 -83.580553
# 2          Arby's      US  35.782339 -83.551408
# 3  Steak 'n Shake      US  33.562738 -84.321143
# 4         Wendy's      US  42.368823 -83.138251
#
#                                  Street Adress  price_level  rating  \
# 0        800 N Canal Blvd, Thibodaux, LA 70301          1.0     4.3
# 1  206 Wears Valley Rd, Pigeon Forge, TN 37863          1.0     3.3
# 2         3652 Parkway, Pigeon Forge, TN 37863          1.0     3.9
# 3       2118 Mt Zion Parkway, Morrow, GA 30260          1.0     3.4
# 4      9768 Grand River Ave, Detroit, MI 48204          1.0     3.6
#
#    user_ratings_total
# 0               479.0
# 1              1029.0
# 2              1620.0
# 3              5287.0
# 4              1560.0

# %%
fastfood_us_df.dropna()
# Out:
#                 name country   latitude  longitude  \
# 0     Sonic Drive-In      US  29.814697 -90.814742
# 1          Taco Bell      US  35.803788 -83.580553
# 2             Arby's      US  35.782339 -83.551408
# 3     Steak 'n Shake      US  33.562738 -84.321143
# 4            Wendy's      US  42.368823 -83.138251
# ...              ...     ...        ...        ...
# 9296       Pizza Hut      US  36.078802 -80.387508
# 9297       Pizza Hut      US  36.117563 -80.316553
# 9298       Pizza Hut      US  36.077718 -80.176748
# 9299       Pizza Hut      US  36.111015 -80.089165
# 9301       Pizza Hut      US  34.632778 -78.624615
#
#                                       Street Adress  price_level  rating  \
# 0             800 N Canal Blvd, Thibodaux, LA 70301          1.0     4.3
# 1       206 Wears Valley Rd, Pigeon Forge, TN 37863          1.0     3.3
# 2              3652 Parkway, Pigeon Forge, TN 37863          1.0     3.9
# 3            2118 Mt Zion Parkway, Morrow, GA 30260          1.0     3.4
# 4           9768 Grand River Ave, Detroit, MI 48204          1.0     3.6
# ...                                             ...          ...     ...
# 9296     5062 Styers Ferry Rd, Lewisville, NC 27023          1.0     3.6
# 9297     3460 Robinhood Rd, Winston-Salem, NC 27106          2.0     4.5
# 9298  3069 Kernersville Rd, Winston-Salem, NC 27107          1.0     4.6
# 9299          838 S Main St, Kernersville, NC 27284          1.0     3.2
# 9301       1405 W Broad St, Elizabethtown, NC 28337          1.0     3.7
#
#       user_ratings_total
# 0                  479.0
# 1                 1029.0
# 2                 1620.0
# 3                 5287.0
# 4                 1560.0
# ...                  ...
# 9296               230.0
# 9297               387.0
# 9298              1488.0
# 9299               644.0
# 9301               314.0
#
# [7821 rows x 8 columns]

# %%
fastfood_us_df.to_csv('fastfood_restaurant_review.csv', index = False)
